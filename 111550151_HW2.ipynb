# %%
import matplotlib.pyplot as plt
import numpy as np

# Color choices
violet = (68/255.0, 0, 99.5/255.0)
orchid = (184/255.0, 96/255.0, 231/255.0)
lavenderpink = (1, 143/255.0, 176/255.0)
razz = (235/255.0, 0, 160/255.0)
plt.figure(figsize=(10, 7))
plt.rcParams['lines.linewidth'] = 0.75

# Some functions
def linear_bezier(t, P0, P1):
  return P0 + t * (P1 - P0)

def cubic_bezier(t, P0, P1, P2, P3):
  return (1 - t) ** 3 * P0 + 3 * (1 - t) ** 2 * t * P1 + 3 * (1 - t) * t ** 2 * P2 + t ** 3 * P3

# Color lines 1
t = np.linspace(0.59, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.55, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=violet)

t = np.linspace(0.5, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.45, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.4, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.3, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.2, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=violet)

t = np.linspace(0.07, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=violet)

t = np.linspace(0.15, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=violet)

t = np.linspace(0.2, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=violet)

t = np.linspace(0.29, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=violet)

t = np.linspace(0.35, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=violet)

t = np.linspace(0.4, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=violet)

t = np.linspace(0.47, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=violet)

t = np.linspace(0.54, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=violet)

t = np.linspace(0.6, 0.924, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=violet)

t = np.linspace(0.66, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=violet)

t = np.linspace(0.73, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=violet)

t = np.linspace(0.8, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=violet)

t = np.linspace(0.86, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=violet)

t = np.linspace(0.91, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.77, -2.415]), np.array([-4.74, -3.757]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 20, bezier_points[:, 1], color=violet)

# Color lines 2
t = np.linspace(0, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.5041, -4.5314]), np.array([-1.4613, -4.4754]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.55134, -4.50783]), np.array([-1.486924, -4.416832]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.597121, -4.484764]), np.array([-1.51, -4.3636]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.63725, -4.46436]), np.array([-1.53092, -4.31623]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.681, -4.4414]), np.array([-1.5535, -4.2672]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.727, -4.417]), np.array([-1.5766, -4.2143]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.779, -4.3892]), np.array([-1.598, -4.166]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.829, -4.362]), np.array([-1.6216, -4.1143]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.885, -4.328]), np.array([-1.652, -4.048]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.946, -4.3005]), np.array([-1.679, -3.98]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-2.004, -4.271]), np.array([-1.704, -3.918]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-2.0375, -4.1945]), np.array([-1.7354, -3.852]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-2.031, -4.089]), np.array([-1.7624, -3.7922]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-2.021, -3.977]), np.array([-1.79, -3.728]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-2.012, -3.8617]), np.array([-1.8235, -3.665]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-2.0035, -3.767]), np.array([-1.8435, -3.6088]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.997, -3.6642]), np.array([-1.8679, -3.5513]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.988, -3.5796]), np.array([-1.894, -3.499]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.988, -3.5796]), np.array([-1.894, -3.499]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.983, -3.501]), np.array([-1.915, -3.445]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.9783, -3.4322]), np.array([-1.9345, -3.3964]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.9707, -3.3636]), np.array([-1.956, -3.3534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

# Color lines 3
bezier_points = np.array([linear_bezier(t, np.array([-1.404, -4.0104]), np.array([-1.462, -3.306]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-1.343, -3.92]), np.array([-1.408, -3.278]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-1.286, -3.814]), np.array([-1.348, -3.25]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-1.216, -3.717]), np.array([-1.275, -3.216]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-1.155, -3.607]), np.array([-1.22, -3.186]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-1.093, -3.55]), np.array([-1.165, -3.142]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-1.042, -3.482]), np.array([-1.114, -3.113]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.99, -3.408]), np.array([-1.055, -3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.932, -3.333]), np.array([-1.002, -3.038]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.882, -3.257]), np.array([-0.9475, -3.01]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.832, -3.179]), np.array([-0.894, -2.979]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.789, -3.121]), np.array([-0.845, -2.945]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.753, -3.07]), np.array([-0.8, -2.919]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.718, -3.023]), np.array([-0.759, -2.893]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.68, -2.967]), np.array([-0.712, -2.867]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.6477, -2.9286]), np.array([-0.6786, -2.84]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.62, -2.889]), np.array([-0.644, -2.819]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.5953, -2.853]), np.array([-0.6137, -2.7985]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.574, -2.824]), np.array([-0.589, -2.7825]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.556, -2.7992]), np.array([-0.5673, -2.7693]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.54, -2.778]), np.array([-0.5496, -2.7567]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.5273, -2.7621]), np.array([-0.5345, -2.7474]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.518, -2.7492]), np.array([-0.5227, -2.7399]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

# Color lines 4
bezier_points = np.array([linear_bezier(t, np.array([-1.411, -4.118]), np.array([-1.141, -3.721]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.375, -4.153]), np.array([-1.103, -3.743]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.34, -4.185]), np.array([-1.062, -3.766]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.314, -4.226]), np.array([-1.013, -3.778]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.2785, -4.263]), np.array([-0.971, -3.806]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.242, -4.305]), np.array([-0.926, -3.828]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.204, -4.347]), np.array([-0.877, -3.848]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.162, -4.388]), np.array([-0.827, -3.864]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.12, -4.431]), np.array([-0.782, -3.891]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.078, -4.47]), np.array([-0.731, -3.915]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-1.036, -4.516]), np.array([-0.675, -3.934]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-0.992, -4.563]), np.array([-0.632, -3.962]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-0.95, -4.611]), np.array([-0.587, -3.978]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-0.907, -4.665]), np.array([-0.528, -4.008]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-0.856, -4.723]), np.array([-0.468, -4.04]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-0.798, -4.765]), np.array([-0.414, -4.068]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([-0.749, -4.817]), np.array([-0.36, -4.093]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

# Color lines 5
bezier_points = np.array([linear_bezier(t, np.array([1.994, -4.2344]), np.array([1.9935, -4.259]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.956, -4.167]), np.array([1.949, -4.258]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.916, -4.103]), np.array([1.899, -4.258]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.88, -4.05]), np.array([1.852, -4.255]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.88, -4.05]), np.array([1.852, -4.255]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.84, -3.985]), np.array([1.805, -4.247]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.799, -3.922]), np.array([1.745, -4.242]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.761, -3.874]), np.array([1.693, -4.231]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.724, -3.823]), np.array([1.637, -4.226]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.693, -3.76]), np.array([1.578, -4.227]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.657, -3.703]), np.array([1.523, -4.22]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.62, -3.643]), np.array([1.468, -4.218]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.58, -3.584]), np.array([1.412, -4.218]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.545, -3.526]), np.array([1.357, -4.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.511, -3.467]), np.array([1.303, -4.209]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.477, -3.41]), np.array([1.24, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.448, -3.353]), np.array([1.183, -4.195]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.4, -3.364]), np.array([1.149, -4.133]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.346, -3.388]), np.array([1.113, -4.07]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.292, -3.404]), np.array([1.083, -4.004]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.241, -3.421]), np.array([1.049, -3.948]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.189, -3.4326]), np.array([1.016, -3.883]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.137, -3.451]), np.array([0.988, -3.8266]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.088, -3.4674]), np.array([0.959, -3.7776]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([1.038, -3.481]), np.array([0.934, -3.726]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([0.979, -3.506]), np.array([0.903, -3.664]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([0.907, -3.531]), np.array([0.872, -3.602]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

# Color lines 6
bezier_points = np.array([linear_bezier(t, np.array([0.832, -3.5]), np.array([0.79, -3.529]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.854, -3.429]), np.array([0.724, -3.512]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.2425, -2.494]), np.array([0.194, -2.506]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.291, -2.512]), np.array([0.203, -2.536]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.35, -2.533]), np.array([0.221, -2.573]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.415, -2.555]), np.array([0.234, -2.617]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.492, -2.576]), np.array([0.251, -2.66]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.566, -2.6]), np.array([0.261, -2.706]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.62, -2.628]), np.array([0.283, -2.751]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.69, -2.65]), np.array([0.297, -2.802]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.785, -2.664]), np.array([0.311, -2.858]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.86, -2.68]), np.array([0.324, -2.907]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.962, -2.69]), np.array([0.337, -2.959]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([1.072, -2.692]), np.array([0.358, -3.01]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([1.088, -2.727]), np.array([0.38, -3.063]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([1.074, -2.779]), np.array([0.395, -3.115]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([1.06, -2.833]), np.array([0.414, -3.171]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([1.03, -2.903]), np.array([0.428, -3.233]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.997, -2.982]), np.array([0.44, -3.297]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.977, -3.055]), np.array([0.463, -3.35]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.937, -3.141]), np.array([0.482, -3.41]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.916, -3.215]), np.array([0.503, -3.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.903, -3.277]), np.array([0.564, -3.483]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([0.885, -3.348]), np.array([0.64, -3.498]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

# Color lines 7
bezier_points = np.array([linear_bezier(t, np.array([-1.7265, -2.166]), np.array([-1.701, -2.174]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.718, -2.1965]), np.array([-1.665, -2.209]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.712, -2.228]), np.array([-1.62, -2.2535]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.708, -2.264]), np.array([-1.572, -2.304]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.707, -2.304]), np.array([-1.517, -2.355]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.7026, -2.339]), np.array([-1.4525, -2.41]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.703, -2.381]), np.array([-1.389, -2.473]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.697, -2.433]), np.array([-1.324, -2.533]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.7, -2.483]), np.array([-1.258, -2.599]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.7, -2.524]), np.array([-1.27, -2.642]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.704, -2.564]), np.array([-1.286, -2.682]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.706, -2.599]), np.array([-1.295, -2.718]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.712, -2.638]), np.array([-1.314, -2.753]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.713, -2.67]), np.array([-1.33, -2.787]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.719, -2.705]), np.array([-1.34, -2.821]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.722, -2.745]), np.array([-1.352, -2.86]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.734, -2.783]), np.array([-1.369, -2.9]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.724, -2.832]), np.array([-1.382, -2.94]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.711, -2.874]), np.array([-1.401, -2.981]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.684, -2.927]), np.array([-1.414, -3.024]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.657, -2.986]), np.array([-1.427, -3.072]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.627, -3.044]), np.array([-1.447, -3.115]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.6, -3.102]), np.array([-1.4595, -3.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.5826, -3.155]), np.array([-1.4683, -3.1983]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

bezier_points = np.array([linear_bezier(t, np.array([-1.56, -3.212]), np.array([-1.484, -3.241]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

# Color lines 8
bezier_points = np.array([linear_bezier(t, np.array([-0.902, -2.92]), np.array([-0.856, -2.896]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-0.944, -2.875]), np.array([-0.828, -2.81]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-0.986, -2.831]), np.array([-0.799, -2.723]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.033, -2.784]), np.array([-0.767, -2.623]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.074, -2.739]), np.array([-0.736, -2.531]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.124, -2.692]), np.array([-0.705, -2.442]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.164, -2.652]), np.array([-0.681, -2.366]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.21, -2.618]), np.array([-0.7, -2.315]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.25, -2.576]), np.array([-0.784, -2.307]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.289, -2.541]), np.array([-0.857, -2.292]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.329, -2.504]), np.array([-0.94, -2.285]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.361, -2.46]), np.array([-1.015, -2.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.404, -2.432]), np.array([-1.086, -2.26]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.447, -2.4]), np.array([-1.157, -2.245]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.476, -2.367]), np.array([-1.214, -2.233]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.515, -2.34]), np.array([-1.275, -2.223]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.545, -2.305]), np.array([-1.344, -2.215]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.574, -2.27]), np.array([-1.404, -2.2006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.613, -2.2385]), np.array([-1.472, -2.1906]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.651, -2.204]), np.array([-1.5505, -2.1787]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

bezier_points = np.array([linear_bezier(t, np.array([-1.691, -2.175]), np.array([-1.622, -2.163]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

# Color lines 9
bezier_points = np.array([linear_bezier(t, np.array([-0.268, -4.061]), np.array([-0.52, -3.345]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.23, -4.043]), np.array([-0.475, -3.351]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.192, -4.026]), np.array([-0.429, -3.353]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.159, -4.005]), np.array([-0.383, -3.36]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.12, -3.985]), np.array([-0.334, -3.38]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.077, -3.975]), np.array([-0.29, -3.378]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.043, -3.95]), np.array([-0.243, -3.38]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([-0.007, -3.932]), np.array([-0.197, -3.398]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.036, -3.914]), np.array([-0.152, -3.398]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.075, -3.897]), np.array([-0.103, -3.405]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.113, -3.877]), np.array([-0.058, -3.417]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.153, -3.861]), np.array([-0.016, -3.418]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.192, -3.839]), np.array([0.025, -3.4233]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.228, -3.821]), np.array([0.071, -3.436]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.264, -3.808]), np.array([0.114, -3.445]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.301, -3.784]), np.array([0.153, -3.446]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.3406, -3.762]), np.array([0.201, -3.453]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.386, -3.743]), np.array([0.2515, -3.459]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.428, -3.72]), np.array([0.304, -3.472]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.471, -3.703]), np.array([0.355, -3.48]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.513, -3.683]), np.array([0.408, -3.482]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.557, -3.663]), np.array([0.463, -3.493]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.595, -3.641]), np.array([0.512, -3.499]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.633, -3.625]), np.array([0.5625, -3.509]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.67, -3.608]), np.array([0.6114, -3.5155]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.7034, -3.594]), np.array([0.659, -3.522]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.7435, -3.574]), np.array([0.718, -3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

bezier_points = np.array([linear_bezier(t, np.array([0.7737, -3.5566]), np.array([0.7605, -3.5342]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

# Color lines 10
bezier_points = np.array([linear_bezier(t, np.array([2.568, -3.689]), np.array([2.035, -4.238]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([2.474, -3.703]), np.array([1.991, -4.176]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([2.38, -3.707]), np.array([1.95, -4.107]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([2.279, -3.707]), np.array([1.908, -4.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([2.183, -3.703]), np.array([1.867, -3.969]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([2.108, -3.688]), np.array([1.822, -3.913]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([2.037, -3.666]), np.array([1.79, -3.856]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.989, -3.629]), np.array([1.7505, -3.799]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.938, -3.594]), np.array([1.714, -3.738]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.893, -3.557]), np.array([1.677, -3.687]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.86, -3.521]), np.array([1.645, -3.6384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.831, -3.482]), np.array([1.616, -3.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.808, -3.4464]), np.array([1.5895, -3.5515]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.782, -3.407]), np.array([1.565, -3.508]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.757, -3.3636]), np.array([1.536, -3.463]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.738, -3.326]), np.array([1.5076, -3.419]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

bezier_points = np.array([linear_bezier(t, np.array([1.724, -3.288]), np.array([1.482, -3.377]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

# Color lines 11
t = np.linspace(0.24, 0.27, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.215, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.19, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.34, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.15, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.13, 0.39, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.115, 0.42, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.099, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.092, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.08, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.07, 0.53, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.065, 0.56, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.06, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.06, 0.61, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.06, 0.64, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=razz)

t = np.linspace(0.065, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=razz)

t = np.linspace(0.07, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=razz)

t = np.linspace(0.079, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=razz)

t = np.linspace(0.25, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=razz)

t = np.linspace(0.35, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 20, bezier_points[:, 1], color=razz)

t = np.linspace(0.46, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 21, bezier_points[:, 1], color=razz)

t = np.linspace(0.57, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 22, bezier_points[:, 1], color=razz)

t = np.linspace(0.68, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 23, bezier_points[:, 1], color=razz)

t = np.linspace(0.78, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 24, bezier_points[:, 1], color=razz)

t = np.linspace(0.89, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.66, -5.1]), np.array([-0.66, -4.2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 25, bezier_points[:, 1], color=razz)

# Color lines 12
t = np.linspace(0.82, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.72, 0.79, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=violet)

t = np.linspace(0.64, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.57, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.51, 0.62, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.45, 0.56, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.4, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=violet)

t = np.linspace(0.35, 0.48, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=violet)

t = np.linspace(0.31, 0.44, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=violet)

t = np.linspace(0.27, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=violet)

t = np.linspace(0.24, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=violet)

t = np.linspace(0.21, 0.34, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=violet)

t = np.linspace(0.18, 0.323, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=violet)

t = np.linspace(0.15, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=violet)

t = np.linspace(0.13, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=violet)

t = np.linspace(0.11, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=violet)

t = np.linspace(0.1, 0.28, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=violet)

t = np.linspace(0.08, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=violet)

t = np.linspace(0.07, 0.31, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=violet)

t = np.linspace(0.07, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=violet)

t = np.linspace(0.06, 0.31, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 20, bezier_points[:, 1], color=violet)

t = np.linspace(0.06, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 21, bezier_points[:, 1], color=violet)

t = np.linspace(0.07, 0.28, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 22, bezier_points[:, 1], color=violet)

t = np.linspace(0.08, 0.27, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 23, bezier_points[:, 1], color=violet)

t = np.linspace(0.09, 0.25, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 24, bezier_points[:, 1], color=violet)

t = np.linspace(0.11, 0.24, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 25, bezier_points[:, 1], color=violet)

t = np.linspace(0.14, 0.23, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 26, bezier_points[:, 1], color=violet)

t = np.linspace(0.2, 0.21, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.285, 2.725]), np.array([-1.95, 1.797]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 27, bezier_points[:, 1], color=violet)

# Color lines 13
t = np.linspace(0.1, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.16, 0.49, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=violet)

t = np.linspace(0.24, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.3, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.34, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.38, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.4, 0.856, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=violet)

t = np.linspace(0.42, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=violet)

t = np.linspace(0.42, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=violet)

t = np.linspace(0.4, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=violet)

t = np.linspace(0.38, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=violet)

t = np.linspace(0.34, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=violet)

t = np.linspace(0.29, 0.38, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.216, 2.48]), np.array([1.352, 2.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=violet)

# Color lines 14
t = np.linspace(0.605, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 14, bezier_points[:, 1], color=razz)

t = np.linspace(0.634, 0.676, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.662, 0.716, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.689, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.445, 0.46, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.707, 0.778, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.405, 0.449, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.365, 0.43, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.728, 0.805, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.742, 0.822, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.33, 0.415, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.756, 0.845, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.3, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.77, 0.867, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.26, 0.38, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.78, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.22, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.189, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.79, 0.895, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.167, 0.34, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.8, 0.909, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.34, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.8, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.133, 0.33, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.8, 0.925, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.798, 0.932, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.165, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.79, 0.935, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.105, 0.305, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.78, 0.935, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.1, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.77, 0.928, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.11, 0.28, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.76, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.12, 0.268, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.74, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.129, 0.25, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.7, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.15, 0.24, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.67, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.62, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.166, 0.224, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.18, 0.21, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.56, 0.79, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.47, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.19, 0.2, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.24, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1, -0.21]), np.array([0.61, -1.053]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

# Color lines 15
t = np.linspace(0.24, 0.44, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.17, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.1, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.06, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.64, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.07, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.73, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.16, 0.36, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.73, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.3, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.47, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.985, 1.835]), np.array([-1.24, 1.333]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

# Color lines 16
t = np.linspace(0.35, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.01, bezier_points[:, 1], color='black')

t = np.linspace(0.23, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

t = np.linspace(0.18, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01, bezier_points[:, 1], color='black')

t = np.linspace(0.14, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 2, bezier_points[:, 1], color='black')

t = np.linspace(0.12, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 3, bezier_points[:, 1], color='black')

t = np.linspace(0.11, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 4, bezier_points[:, 1], color='black')

t = np.linspace(0.1, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 5, bezier_points[:, 1], color='black')

t = np.linspace(0.1, 0.799, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 6, bezier_points[:, 1], color='black')

t = np.linspace(0.105, 0.825, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 7, bezier_points[:, 1], color='black')

t = np.linspace(0.115, 0.839, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 8, bezier_points[:, 1], color='black')

t = np.linspace(0.125, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 9, bezier_points[:, 1], color='black')

t = np.linspace(0.14, 0.878, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 10, bezier_points[:, 1], color='black')

t = np.linspace(0.16, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 11, bezier_points[:, 1], color='black')

t = np.linspace(0.18, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 12, bezier_points[:, 1], color='black')

t = np.linspace(0.2, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 13, bezier_points[:, 1], color='black')

t = np.linspace(0.22, 0.905, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 14, bezier_points[:, 1], color='black')

t = np.linspace(0.25, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 15, bezier_points[:, 1], color='black')

t = np.linspace(0.28, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 16, bezier_points[:, 1], color='black')

t = np.linspace(0.31, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 17, bezier_points[:, 1], color='black')

t = np.linspace(0.35, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 18, bezier_points[:, 1], color='black')

t = np.linspace(0.4, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 19, bezier_points[:, 1], color='black')

t = np.linspace(0.46, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 20, bezier_points[:, 1], color='black')

t = np.linspace(0.55, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.857, 1.704]), np.array([-0.999, 1.458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 21, bezier_points[:, 1], color='black')

# Color lines 17
t = np.linspace(0.43, 0.66, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

t = np.linspace(0.32, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01, bezier_points[:, 1], color='black')

t = np.linspace(0.25, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 2, bezier_points[:, 1], color='black')

t = np.linspace(0.18, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 3, bezier_points[:, 1], color='black')

t = np.linspace(0.13, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 4, bezier_points[:, 1], color='black')

t = np.linspace(0.09, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 5, bezier_points[:, 1], color='black')

t = np.linspace(0.07, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 6, bezier_points[:, 1], color='black')

t = np.linspace(0.05, 0.96, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 7, bezier_points[:, 1], color='black')

t = np.linspace(0.04, 0.96, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 8, bezier_points[:, 1], color='black')

t = np.linspace(0.05, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 9, bezier_points[:, 1], color='black')

t = np.linspace(0.06, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 10, bezier_points[:, 1], color='black')

t = np.linspace(0.01, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 11, bezier_points[:, 1], color='black')

t = np.linspace(0.13, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 12, bezier_points[:, 1], color='black')

t = np.linspace(0.2, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 13, bezier_points[:, 1], color='black')

t = np.linspace(0.25, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 14, bezier_points[:, 1], color='black')

t = np.linspace(0.35, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.315, 1.702]), np.array([1.388, 1.885]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.01 * 15, bezier_points[:, 1], color='black')

# Color lines 18
t = np.linspace(0.5, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.2, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.05, 0.33, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.71, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.05, 0.25, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.72, 0.909, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.03, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.03, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.04, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.2, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.1406, 1.5987]), np.array([1.347, 1.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

# Color lines 19
t = np.linspace(0.29, 0.33, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

t = np.linspace(0.285, 0.38, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04, bezier_points[:, 1], color='black')

t = np.linspace(0.28, 0.42, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 2, bezier_points[:, 1], color='black')

t = np.linspace(0.27, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 3, bezier_points[:, 1], color='black')

t = np.linspace(0.33, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 4, bezier_points[:, 1], color='black')

t = np.linspace(0.38, 0.56, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 5, bezier_points[:, 1], color='black')

t = np.linspace(0.44, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 6, bezier_points[:, 1], color='black')

t = np.linspace(0.5, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 7, bezier_points[:, 1], color='black')

t = np.linspace(0.56, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 8, bezier_points[:, 1], color='black')

t = np.linspace(0.6, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 9, bezier_points[:, 1], color='black')

t = np.linspace(0.65, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 10, bezier_points[:, 1], color='black')

t = np.linspace(0.69, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 11, bezier_points[:, 1], color='black')

t = np.linspace(0.73, 0.79, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 12, bezier_points[:, 1], color='black')

t = np.linspace(0.76, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 13, bezier_points[:, 1], color='black')

t = np.linspace(0.79, 0.826, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 14, bezier_points[:, 1], color='black')

t = np.linspace(0.81, 0.845, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 15, bezier_points[:, 1], color='black')

t = np.linspace(0.83, 0.857, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 16, bezier_points[:, 1], color='black')

t = np.linspace(0.845, 0.863, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 17, bezier_points[:, 1], color='black')

t = np.linspace(0.855, 0.869, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 18, bezier_points[:, 1], color='black')

t = np.linspace(0.87, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.41, 1.14]), np.array([-1.61, 1.93]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.04 * 19, bezier_points[:, 1], color='black')

# Color lines 20
t = np.linspace(0.38, 0.41, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

t = np.linspace(0.48, 0.56, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05, bezier_points[:, 1], color='black')

t = np.linspace(0.56, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 2, bezier_points[:, 1], color='black')

t = np.linspace(0.63, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 3, bezier_points[:, 1], color='black')

t = np.linspace(0.69, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 4, bezier_points[:, 1], color='black')

t = np.linspace(0.74, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 5, bezier_points[:, 1], color='black')

t = np.linspace(0.78, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 6, bezier_points[:, 1], color='black')

t = np.linspace(0.8, 0.97, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 7, bezier_points[:, 1], color='black')

t = np.linspace(0.82, 0.98, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 8, bezier_points[:, 1], color='black')

t = np.linspace(0.84, 0.99, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 9, bezier_points[:, 1], color='black')

t = np.linspace(0.84, 0.989, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 10, bezier_points[:, 1], color='black')

t = np.linspace(0.83, 0.97, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 11, bezier_points[:, 1], color='black')

t = np.linspace(0.815, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 12, bezier_points[:, 1], color='black')

t = np.linspace(0.788, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 13, bezier_points[:, 1], color='black')

t = np.linspace(0.75, 0.876, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 14, bezier_points[:, 1], color='black')

t = np.linspace(0.7, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 15, bezier_points[:, 1], color='black')

t = np.linspace(0.62, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 16, bezier_points[:, 1], color='black')

t = np.linspace(0.54, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 17, bezier_points[:, 1], color='black')

t = np.linspace(0.42, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 18, bezier_points[:, 1], color='black')

t = np.linspace(0.34, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 19, bezier_points[:, 1], color='black')

t = np.linspace(0.38, 0.49, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.987, 1.517]), np.array([1.2, 2.075]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 20, bezier_points[:, 1], color='black')

# Color lines 21
t = np.linspace(0.43, 0.46, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.78, 0.98, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.23, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.05, color=lavenderpink)

t = np.linspace(0.87, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.05, color=lavenderpink)

t = np.linspace(0.11, 0.2, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.05 * 2, color=lavenderpink)

t = np.linspace(0.874, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.05 * 2, color=lavenderpink)

t = np.linspace(0, 0.15, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.05 * 3, color=lavenderpink)

t = np.linspace(0.03, 0.1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.322, 1.204]), np.array([-0.148, 1.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.05 * 4, color=lavenderpink)

# Color lines 22
t = np.linspace(0.66, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.197, -1.1924]), np.array([-1.118, -0.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.49, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.197, -1.1924]), np.array([-1.118, -0.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03, bezier_points[:, 1], color=violet)

t = np.linspace(0.36, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.197, -1.1924]), np.array([-1.118, -0.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.26, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.197, -1.1924]), np.array([-1.118, -0.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.17, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.197, -1.1924]), np.array([-1.118, -0.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.1, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.197, -1.1924]), np.array([-1.118, -0.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.07, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.197, -1.1924]), np.array([-1.118, -0.992]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 6, bezier_points[:, 1], color=violet)

# Color lines 23
t = np.linspace(0.145, 0.155, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.165, 0.198, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.18, 0.24, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.197, 0.285, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.217, 0.324, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.237, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.257, 0.41, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.268, 0.458, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.289, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.305, 0.54, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.32, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.34, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.353, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.37, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.387, 0.695, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.403, 0.713, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=razz)

t = np.linspace(0.42, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=razz)

t = np.linspace(0.435, 0.743, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=razz)

t = np.linspace(0.4544, 0.756, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=razz)

t = np.linspace(0.472, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=razz)

t = np.linspace(0.49, 0.788, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=razz)

t = np.linspace(0.507, 0.802, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 20, bezier_points[:, 1], color=razz)

t = np.linspace(0.523, 0.815, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 21, bezier_points[:, 1], color=razz)

t = np.linspace(0.54, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 22, bezier_points[:, 1], color=razz)

t = np.linspace(0.557, 0.846, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 23, bezier_points[:, 1], color=razz)

t = np.linspace(0.574, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 24, bezier_points[:, 1], color=razz)

t = np.linspace(0.64, 0.875, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 25, bezier_points[:, 1], color=razz)

t = np.linspace(0.7, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 26, bezier_points[:, 1], color=razz)

t = np.linspace(0.78, 0.905, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 27, bezier_points[:, 1], color=razz)

t = np.linspace(0.84, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 28, bezier_points[:, 1], color=razz)

t = np.linspace(0.9, 0.935, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.94, 0.847]), np.array([-2.72, -1.157]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 29, bezier_points[:, 1], color=razz)

# Color lines 24
t = np.linspace(0.542, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.44, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09, bezier_points[:, 1], color=orchid)

t = np.linspace(0.32, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.22, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.13, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.12, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.11, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.1, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 7, bezier_points[:, 1], color=orchid)

t = np.linspace(0.09, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 8, bezier_points[:, 1], color=orchid)

t = np.linspace(0.08, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 9, bezier_points[:, 1], color=orchid)

t = np.linspace(0.076, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 10, bezier_points[:, 1], color=orchid)

t = np.linspace(0.07, 0.36, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 11, bezier_points[:, 1], color=orchid)

t = np.linspace(0.06, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 12, bezier_points[:, 1], color=orchid)

t = np.linspace(0.05, 0.2, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 13, bezier_points[:, 1], color=orchid)

t = np.linspace(0.04, 0.1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.772, -0.52]), np.array([-2.376, 1.168]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.09 * 14, bezier_points[:, 1], color=orchid)

# Color lines 25
t = np.linspace(0.8, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07, color=lavenderpink)

t = np.linspace(0.72, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.62, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=lavenderpink)

t = np.linspace(0.52, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=lavenderpink)

t = np.linspace(0.42, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=lavenderpink)

t = np.linspace(0.32, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=lavenderpink)

t = np.linspace(0.22, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=lavenderpink)

t = np.linspace(0.12, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=lavenderpink)

t = np.linspace(0.06, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=lavenderpink)

t = np.linspace(0.12, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=lavenderpink)

t = np.linspace(0.17, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=lavenderpink)

t = np.linspace(0.24, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=lavenderpink)

t = np.linspace(0.35, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=lavenderpink)

t = np.linspace(0.42, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=lavenderpink)

t = np.linspace(0.52, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=lavenderpink)

t = np.linspace(0.64, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=lavenderpink)

t = np.linspace(0.79, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.73, -1.03]), np.array([-0.254, -1.204]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=lavenderpink)

# Color lines 26
t = np.linspace(0.7, 0.79, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.55, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=violet)

t = np.linspace(0.4, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.25, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.1, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.2, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.26, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=violet)

t = np.linspace(0.32, 0.898, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=violet)

t = np.linspace(0.39, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=violet)

t = np.linspace(0.46, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=violet)

t = np.linspace(0.54, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=violet)

t = np.linspace(0.61, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=violet)

t = np.linspace(0.68, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=violet)

t = np.linspace(0.75, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=violet)

t = np.linspace(0.82, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=violet)

t = np.linspace(0.89, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.335, -2.683]), np.array([0.09, -0.87]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=violet)

# Color lines 27
t = np.linspace(0.25, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.26, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=razz)

t = np.linspace(0.26, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=razz)

t = np.linspace(0.26, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=razz)

t = np.linspace(0.24, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=razz)

t = np.linspace(0.22, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=razz)

t = np.linspace(0.19, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=razz)

t = np.linspace(0.16, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=razz)

t = np.linspace(0.13, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=razz)

t = np.linspace(0.1, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=razz)

t = np.linspace(0.07, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=razz)

t = np.linspace(0.04, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=razz)

t = np.linspace(0.01, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.2, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=razz)

t = np.linspace(0.43, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.96, 2.143]), np.array([0.165, 1.607]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=razz)

# Color lines 28
t = np.linspace(0.72, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.63, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.53, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.45, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.35, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.26, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.2, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.1, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

t = np.linspace(0.2, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=orchid)

t = np.linspace(0.35, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=orchid)

t = np.linspace(0.5, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=orchid)

t = np.linspace(0.6, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=orchid)

t = np.linspace(0.8, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.905, 1.745]), np.array([1.73, -0.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=orchid)

# Color lines 29
t = np.linspace(0.38, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.35, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=lavenderpink)

t = np.linspace(0.3, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=lavenderpink)

t = np.linspace(0.2, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=lavenderpink)

t = np.linspace(0.08, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=lavenderpink)

t = np.linspace(0.1, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=lavenderpink)

t = np.linspace(0.13, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=lavenderpink)

t = np.linspace(0.16, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=lavenderpink)

t = np.linspace(0.2, 0.825, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=lavenderpink)

t = np.linspace(0.24, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=lavenderpink)

t = np.linspace(0.27, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=lavenderpink)

t = np.linspace(0.29, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=lavenderpink)

t = np.linspace(0.32, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=lavenderpink)

t = np.linspace(0.35, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=lavenderpink)

t = np.linspace(0.38, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=lavenderpink)

t = np.linspace(0.41, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=lavenderpink)

t = np.linspace(0.45, 0.62, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=lavenderpink)

t = np.linspace(0.48, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=lavenderpink)

t = np.linspace(0.5, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.164, -0.704]), np.array([2.674, -0.32]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=lavenderpink)

# Color lines 30
t = np.linspace(0.47, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.43, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.39, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.35, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.3, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.26, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.23, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.19, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.15, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.11, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.07, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.03, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.3, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.23, 1.21]), np.array([0.848, 0.136]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=lavenderpink)

# Color lines 31
t = np.linspace(0.79, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.06, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.08, 0.535, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.74, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.1, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.7, 0.918, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.12, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.68, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.43, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.64, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.16, 0.41, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.62, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.39, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.6, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.19, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.6, 0.798, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.19, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.59, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.2, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.6, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.225, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.62, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.24, 0.345, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.62, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.615, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.25, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.27, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.615, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.6, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=razz)

t = np.linspace(0.29, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=razz)

t = np.linspace(0.3, 0.365, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=razz)

t = np.linspace(0.59, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=razz)

t = np.linspace(0.315, 0.38, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=razz)

t = np.linspace(0.58, 0.715, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=razz)

t = np.linspace(0.33, 0.41, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=razz)

t = np.linspace(0.56, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=razz)

t = np.linspace(0.35, 0.435, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=razz)

t = np.linspace(0.56, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=razz)

t = np.linspace(0.36, 0.48, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=razz)

t = np.linspace(0.53, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=razz)

t = np.linspace(0.39, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 20, bezier_points[:, 1], color=razz)

t = np.linspace(0.4, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 21, bezier_points[:, 1], color=razz)

t = np.linspace(0.41, 0.42, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.624, 3.048]), np.array([-1.673, 2.017]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 22, bezier_points[:, 1], color=razz)

# Color lines 32
t = np.linspace(0.12, 0.16, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.12, 0.24, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=lavenderpink)

t = np.linspace(0.12, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=lavenderpink)

t = np.linspace(0.12, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=lavenderpink)

t = np.linspace(0.13, 0.39, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=lavenderpink)

t = np.linspace(0.135, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=lavenderpink)

t = np.linspace(0.137, 0.48, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=lavenderpink)

t = np.linspace(0.14, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=lavenderpink)

t = np.linspace(0.15, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=lavenderpink)

t = np.linspace(0.15, 0.598, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=lavenderpink)

t = np.linspace(0.15, 0.64, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=lavenderpink)

t = np.linspace(0.15, 0.66, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=lavenderpink)

t = np.linspace(0.156, 0.689, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=lavenderpink)

t = np.linspace(0.16, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=lavenderpink)

t = np.linspace(0.16, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=lavenderpink)

t = np.linspace(0.16, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=lavenderpink)

t = np.linspace(0.19, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=lavenderpink)

t = np.linspace(0.17, 0.789, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=lavenderpink)

t = np.linspace(0.18, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=lavenderpink)

t = np.linspace(0.18, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=lavenderpink)

t = np.linspace(0.18, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 20, color=lavenderpink)

t = np.linspace(0.18, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 21, color=lavenderpink)

t = np.linspace(0.26, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 22, color=lavenderpink)

t = np.linspace(0.8, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.484, 3.95]), np.array([-2.81, 3.56]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 23, color=lavenderpink)

# Color lines 33
t = np.linspace(0.04, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.06, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=lavenderpink)

t = np.linspace(0.08, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=lavenderpink)

t = np.linspace(0.1, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=lavenderpink)

t = np.linspace(0.1, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=lavenderpink)

t = np.linspace(0.15, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=lavenderpink)

t = np.linspace(0.17, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=lavenderpink)

t = np.linspace(0.2, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=lavenderpink)

t = np.linspace(0.22, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=lavenderpink)

t = np.linspace(0.3, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=lavenderpink)

t = np.linspace(0.43, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=lavenderpink)

t = np.linspace(0.58, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.984, 3.704]), np.array([-0.035, 3.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=lavenderpink)

# Color lines 34
t = np.linspace(0.22, 0.28, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.21, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.2, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.19, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.18, 0.61, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.15, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.12, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.11, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.09, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.08, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.07, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.05, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.04, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=razz)

t = np.linspace(0.02, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=razz)

t = np.linspace(0, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=razz)

t = np.linspace(0, 0.15, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.28, 3.236]), np.array([0.57, 2.335]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=razz)

# Color lines 35
t = np.linspace(0, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07, color=violet)

t = np.linspace(0.03, 0.98, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 2, color=violet)

t = np.linspace(0.06, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 3, color=violet)

t = np.linspace(0.08, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 4, color=violet)

t = np.linspace(0.11, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 5, color=violet)

t = np.linspace(0.14, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 6, color=violet)

t = np.linspace(0.16, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 7, color=violet)

t = np.linspace(0.19, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 8, color=violet)

t = np.linspace(0.22, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 9, color=violet)

t = np.linspace(0.24, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 10, color=violet)

t = np.linspace(0.27, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 11, color=violet)

t = np.linspace(0.3, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 12, color=violet)

t = np.linspace(0.32, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 13, color=violet)

t = np.linspace(0.35, 0.43, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.825, 3.203]), np.array([1.824, 3.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 14, color=violet)

# Color lines 36
t = np.linspace(0.86, 0.884, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

t = np.linspace(0.765, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05, bezier_points[:, 1], color='black')

t = np.linspace(0.85, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 2, bezier_points[:, 1], color='black')

t = np.linspace(0.87, 0.915, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 3, bezier_points[:, 1], color='black')

t = np.linspace(0.87, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 4, bezier_points[:, 1], color='black')

t = np.linspace(0.86, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 5, bezier_points[:, 1], color='black')

t = np.linspace(0.83, 0.935, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 6, bezier_points[:, 1], color='black')

t = np.linspace(0.78, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 7, bezier_points[:, 1], color='black')

t = np.linspace(0.85, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 8, bezier_points[:, 1], color='black')

t = np.linspace(0.87, 0.935, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 9, bezier_points[:, 1], color='black')

t = np.linspace(0.87, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 10, bezier_points[:, 1], color='black')

t = np.linspace(0.86, 0.927, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 11, bezier_points[:, 1], color='black')

t = np.linspace(0.85, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 12, bezier_points[:, 1], color='black')

t = np.linspace(0.83, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 13, bezier_points[:, 1], color='black')

t = np.linspace(0.81, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 14, bezier_points[:, 1], color='black')

t = np.linspace(0.77, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 15, bezier_points[:, 1], color='black')

t = np.linspace(0.79, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 16, bezier_points[:, 1], color='black')

t = np.linspace(0.78, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 17, bezier_points[:, 1], color='black')

t = np.linspace(0.76, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 18, bezier_points[:, 1], color='black')

t = np.linspace(0.74, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 19, bezier_points[:, 1], color='black')

t = np.linspace(0.72, 0.79, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 20, bezier_points[:, 1], color='black')

t = np.linspace(0.7, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 21, bezier_points[:, 1], color='black')

t = np.linspace(0.6, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 22, bezier_points[:, 1], color='black')

t = np.linspace(0.615, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 23, bezier_points[:, 1], color='black')

t = np.linspace(0.61, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 24, bezier_points[:, 1], color='black')

t = np.linspace(0.59, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 25, bezier_points[:, 1], color='black')

t = np.linspace(0.52, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 26, bezier_points[:, 1], color='black')

t = np.linspace(0.47, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 27, bezier_points[:, 1], color='black')

t = np.linspace(0.445, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 28, bezier_points[:, 1], color='black')

t = np.linspace(0.39, 0.44, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 29, bezier_points[:, 1], color='black')

t = np.linspace(0.17, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 30, bezier_points[:, 1], color='black')

t = np.linspace(0.15, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 31, bezier_points[:, 1], color='black')

t = np.linspace(0.135, 0.23, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 32, bezier_points[:, 1], color='black')

t = np.linspace(0.12, 0.14, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.08, -0.32]), np.array([0.19, -0.89]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.05 * 33, bezier_points[:, 1], color='black')

# Color lines 37
t = np.linspace(0.88, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=razz)

t = np.linspace(0.89, 0.965, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=razz)

t = np.linspace(0.9, 0.97, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=razz)

t = np.linspace(0.9, 0.972, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=razz)

t = np.linspace(0.9, 0.974, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=razz)

t = np.linspace(0.898, 0.97, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=razz)

t = np.linspace(0.888, 0.957, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=razz)

t = np.linspace(0.88, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=razz)

t = np.linspace(0.02, 0.0269, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=razz)

t = np.linspace(0.86, 0.918, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=razz)

t = np.linspace(0.032, 0.043, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=razz)

t = np.linspace(0.835, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=razz)

t = np.linspace(0.052, 0.068, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=razz)

t = np.linspace(0.0799, 0.11, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=razz)

t = np.linspace(0.8, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=razz)

t = np.linspace(0.746, 0.805, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0.129, 0.17, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0.2, 0.26, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.66, 0.737, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.35, 0.61, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([4.222, 1.1]), np.array([2.756, 1.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=razz)

# Color lines 38
t = np.linspace(0.05, 0.07, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.074, 0.165, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.135, 0.26, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.23, 0.36, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.32, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.41, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.49, 0.699, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.62, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.88, 1]), np.array([2.53, 2.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

# Color lines 39
t = np.linspace(0.34, 0.46, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.29, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=lavenderpink)

t = np.linspace(0.25, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=lavenderpink)

t = np.linspace(0.23, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=lavenderpink)

t = np.linspace(0.2, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=lavenderpink)

t = np.linspace(0.18, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=lavenderpink)

t = np.linspace(0.16, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=lavenderpink)

t = np.linspace(0.14, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=lavenderpink)

t = np.linspace(0.13, 0.46, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=lavenderpink)

t = np.linspace(0.12, 0.43, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=lavenderpink)

t = np.linspace(0.12, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=lavenderpink)

t = np.linspace(0.11, 0.38, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=lavenderpink)

t = np.linspace(0.12, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=lavenderpink)

t = np.linspace(0.12, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=lavenderpink)

t = np.linspace(0.13, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=lavenderpink)

t = np.linspace(0.15, 0.28, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=lavenderpink)

t = np.linspace(0.18, 0.25, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=lavenderpink)

t = np.linspace(0.2, 0.23, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.313, 2.946]), np.array([2.67, 2.74]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=lavenderpink)

# Color lines 40
t = np.linspace(0.445, 0.545, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.38, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=razz)

t = np.linspace(0.33, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=razz)

t = np.linspace(0.29, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=razz)

t = np.linspace(0.24, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=razz)

t = np.linspace(0.2, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=razz)

t = np.linspace(0.16, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=razz)

t = np.linspace(0.13, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=razz)

t = np.linspace(0.1, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=razz)

t = np.linspace(0.07, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=razz)

t = np.linspace(0.05, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=razz)

t = np.linspace(0.12, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=razz)

t = np.linspace(0.18, 0.43, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0.47, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0.25, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.47, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.46, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=razz)

t = np.linspace(0.44, 0.686, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=razz)

t = np.linspace(0.42, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=razz)

t = np.linspace(0.4, 0.657, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=razz)

t = np.linspace(0.38, 0.644, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=razz)

t = np.linspace(0.36, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=razz)

t = np.linspace(0.35, 0.61, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 20, color=razz)

t = np.linspace(0.34, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 21, color=razz)

t = np.linspace(0.33, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 22, color=razz)

t = np.linspace(0.33, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 23, color=razz)

t = np.linspace(0.33, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 24, color=razz)

t = np.linspace(0.34, 0.56, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 25, color=razz)

t = np.linspace(0.35, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 26, color=razz)

t = np.linspace(0.36, 0.54, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 27, color=razz)

t = np.linspace(0.38, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 28, color=razz)

t = np.linspace(0.4, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 29, color=razz)

t = np.linspace(0.42, 0.499, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 30, color=razz)

t = np.linspace(0.45, 0.489, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 31, color=razz)

t = np.linspace(0.472, 0.48, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.13, 3.63]), np.array([1.75, 3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 32, color=razz)

# Color lines 41
t = np.linspace(0.74, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.67, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=orchid)

t = np.linspace(0.6, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=orchid)

t = np.linspace(0.55, 0.832, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=orchid)

t = np.linspace(0.49, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=orchid)

t = np.linspace(0.44, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=orchid)

t = np.linspace(0.4, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=orchid)

t = np.linspace(0.35, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=orchid)

t = np.linspace(0.3, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=orchid)

t = np.linspace(0.26, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=orchid)

t = np.linspace(0.21, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=orchid)

t = np.linspace(0.17, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=orchid)

t = np.linspace(0.12, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=orchid)

t = np.linspace(0.15, 0.64, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=orchid)

t = np.linspace(0.2, 0.61, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=orchid)

t = np.linspace(0.26, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=orchid)

t = np.linspace(0.33, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=orchid)

t = np.linspace(0.4, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=orchid)

t = np.linspace(0.45, 0.54, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=orchid)

t = np.linspace(0.51, 0.526, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.51, 4.5]), np.array([1.36, 4.745]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=orchid)

# Color lines 42
t = np.linspace(0.445, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.415, 0.48, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.38, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.35, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.31, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.28, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.25, 0.595, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.21, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.18, 0.814, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.22, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.25, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.28, 0.64, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.34, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.39, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([0.36, 5.24]), np.array([0.82, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=razz)

# Color lines 43
t = np.linspace(0.17, 0.19, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.18, 0.25, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.19, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.21, 0.38, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.22, 0.44, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.24, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.26, 0.56, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.27, 0.62, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

t = np.linspace(0.29, 0.69, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=orchid)

t = np.linspace(0.313, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=orchid)

t = np.linspace(0.33, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=orchid)

t = np.linspace(0.35, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=orchid)

t = np.linspace(0.37, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=orchid)

t = np.linspace(0.4, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=orchid)

t = np.linspace(0.42, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=orchid)

t = np.linspace(0.44, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=orchid)

t = np.linspace(0.46, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.03, 5.543]), np.array([-0.375, 4.596]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=orchid)

# Color lines 44
t = np.linspace(0.78, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.6, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.36, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.15, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.08, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.07, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.07, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.072, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.078, 0.69, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.1, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.19, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.25, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.32, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.36, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.44, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.5, 0.688, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.58, 0.69, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.64, 0.699, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.69, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-0.74, 5.47]), np.array([-0.95, 4.39]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=lavenderpink)

# Color lines 45
t = np.linspace(0.79, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.57, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.28, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.2, 0.79, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.18, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.165, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.15, 0.69, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.13, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

t = np.linspace(0.12, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=orchid)

t = np.linspace(0.106, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=orchid)

t = np.linspace(0.1, 0.46, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=orchid)

t = np.linspace(0.09, 0.41, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=orchid)

t = np.linspace(0.08, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=orchid)

t = np.linspace(0.07, 0.3, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=orchid)

t = np.linspace(0.06, 0.24, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=orchid)

t = np.linspace(0.05, 0.18, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=orchid)

t = np.linspace(0.05, 0.13, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=orchid)

t = np.linspace(0.04, 0.08, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=orchid)

t = np.linspace(0.025, 0.035, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.835, 5.43]), np.array([-1.23, 4.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=orchid)

# Color lines 46
t = np.linspace(0.44, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.42, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.4, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.38, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.36, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.34, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.32, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.3, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.28, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.26, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.24, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.22, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.2, 0.54, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.18, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

t = np.linspace(0.16, 0.46, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.42, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=razz)

t = np.linspace(0.12, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=razz)

t = np.linspace(0.1, 0.32, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=razz)

t = np.linspace(0.08, 0.28, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=razz)

t = np.linspace(0.1, 0.23, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.99, 3.94]), np.array([-1.74, 5.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=razz)

# Color lines  47
t = np.linspace(0.81, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.74, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=violet)

t = np.linspace(0.67, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=violet)

t = np.linspace(0.6, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=violet)

t = np.linspace(0.52, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=violet)

t = np.linspace(0.44, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=violet)

t = np.linspace(0.36, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=violet)

t = np.linspace(0.3, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=violet)

t = np.linspace(0.23, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=violet)

t = np.linspace(0.15, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=violet)

t = np.linspace(0.09, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=violet)

t = np.linspace(0.15, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=violet)

t = np.linspace(0.25, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=violet)

t = np.linspace(0.3, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=violet)

t = np.linspace(0.4, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=violet)

t = np.linspace(0.46, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=violet)

t = np.linspace(0.5, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=violet)

t = np.linspace(0.55, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=violet)

t = np.linspace(0.59, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=violet)

t = np.linspace(0.63, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=violet)

t = np.linspace(0.67, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 20, color=violet)

t = np.linspace(0.7, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 21, color=violet)

t = np.linspace(0.73, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-1.57, 4.73]), np.array([-2.66, 4.45]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 22, color=violet)

# Color lines 48
t = np.linspace(0.82, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.68, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.57, 0.906, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.48, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.4, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.32, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.25, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.2, 0.886, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

t = np.linspace(0.15, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=orchid)

t = np.linspace(0.12, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=orchid)

t = np.linspace(0.08, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=orchid)

t = np.linspace(0.05, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=orchid)

t = np.linspace(0.01, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.35, 4.54]), np.array([-3.53, 3.074]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=orchid)

# Color lines 49
t = np.linspace(0.767, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.68, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.56, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.46, 0.862, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.36, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.24, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.1, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.24, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.31, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.38, 0.923, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.44, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.51, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.57, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.974, 2.223]), np.array([-3.6, 3.346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

# Color lines 50
t = np.linspace(0.48, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.34, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03, bezier_points[:, 1], color=razz)

t = np.linspace(0.25, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.18, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.13, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.1, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.08, 0.58, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.1, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.78, -0.666]), np.array([-2.604, -0.384]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.03 * 7, bezier_points[:, 1], color=razz)

# Color lines 51
t = np.linspace(0.09, 0.15, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.83, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.908, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.25, 0.897, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.34, 0.883, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.45, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.6, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.73, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.71, 0.26]), np.array([2.3, -1.534]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

# Color lines 52
t = np.linspace(0.49, 0.505, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.47, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=razz)

t = np.linspace(0.45, 0.64, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=razz)

t = np.linspace(0.43, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=razz)

t = np.linspace(0.4, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=razz)

t = np.linspace(0.38, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=razz)

t = np.linspace(0.36, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=razz)

t = np.linspace(0.34, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=razz)

t = np.linspace(0.32, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=razz)

t = np.linspace(0.3, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=razz)

t = np.linspace(0.27, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=razz)

t = np.linspace(0.24, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=razz)

t = np.linspace(0.22, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0.2, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.18, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=razz)

t = np.linspace(0.16, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=razz)

t = np.linspace(0.14, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=razz)

t = np.linspace(0.12, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=razz)

t = np.linspace(0.1, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=razz)

t = np.linspace(0.08, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.907, -2.3]), np.array([1.534, -2.365]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=razz)

# Color lines 53
t = np.linspace(0.1, 0.31, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.14, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=orchid)

t = np.linspace(0.18, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=orchid)

t = np.linspace(0.215, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=orchid)

t = np.linspace(0.26, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=orchid)

t = np.linspace(0.3, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=orchid)

t = np.linspace(0.34, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=orchid)

t = np.linspace(0.375, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=orchid)

t = np.linspace(0.42, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=orchid)

t = np.linspace(0.46, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=orchid)

t = np.linspace(0.49, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=orchid)

t = np.linspace(0.53, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=orchid)

t = np.linspace(0.57, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=orchid)

t = np.linspace(0.61, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=orchid)

t = np.linspace(0.64, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=orchid)

t = np.linspace(0.68, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=orchid)

t = np.linspace(0.715, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([1.66, -2.887]), np.array([1.42, -1.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=orchid)

# Color lines 54
t = np.linspace(0.06, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.1, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07, color=violet)

t = np.linspace(0.14, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 2, color=violet)

t = np.linspace(0.175, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 3, color=violet)

t = np.linspace(0.22, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 4, color=violet)

t = np.linspace(0.31, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 5, color=violet)

t = np.linspace(0.399, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 6, color=violet)

t = np.linspace(0.5, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 7, color=violet)

t = np.linspace(0.6, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 8, color=violet)

t = np.linspace(0.68, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 9, color=violet)

t = np.linspace(0.76, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.055, -1.626]), np.array([3.03, -2.096]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07 * 10, color=violet)

# Color lines 55
t = np.linspace(0.21, 0.26, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.18, 0.33, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.15, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.12, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.09, 0.54, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.05, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.07, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.085, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.1, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.12, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.18, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.24, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.3, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.35, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.4, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.42, 0.53, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.435, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([2.32, -1.916]), np.array([2.16, -3.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=lavenderpink)

# Color lines 56
t = np.linspace(0.1, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.14, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=violet)

t = np.linspace(0.17, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.2, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.23, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.25, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.275, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=violet)

t = np.linspace(0.298, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=violet)

t = np.linspace(0.32, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=violet)

t = np.linspace(0.345, 0.835, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=violet)

t = np.linspace(0.36, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=violet)

t = np.linspace(0.38, 0.825, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=violet)

t = np.linspace(0.4, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=violet)

t = np.linspace(0.415, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=violet)

t = np.linspace(0.43, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=violet)

t = np.linspace(0.445, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=violet)

t = np.linspace(0.46, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=violet)

t = np.linspace(0.47, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([3.486, -2.65]), np.array([2.874, -3.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=violet)

# Color lines 57
t = np.linspace(0.87, 0.915, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.72, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.6, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.5, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.4, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.3, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.23, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.14, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.07, 0.645, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.13, 0.61, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.19, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.24, 0.54, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.298, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.33, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.38, 0.44, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-4.15, 3.24]), np.array([-3.7, 1.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=lavenderpink)

# Color lines 58
t = np.linspace(0.59, 0.66, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.52, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=violet)

t = np.linspace(0.46, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=violet)

t = np.linspace(0.39, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=violet)

t = np.linspace(0.31, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=violet)

t = np.linspace(0.25, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=violet)

t = np.linspace(0.19, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=violet)

t = np.linspace(0.1, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=violet)

t = np.linspace(0.2, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=violet)

t = np.linspace(0.34, 0.825, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=violet)

t = np.linspace(0.47, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=violet)

t = np.linspace(0.58, 0.815, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=violet)

t = np.linspace(0.7, 0.808, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.6, 2.45]), np.array([-2.48, 2.55]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=violet)

# Color lines 59
t = np.linspace(0.62, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.57, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=lavenderpink)

t = np.linspace(0.52, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=lavenderpink)

t = np.linspace(0.47, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=lavenderpink)

t = np.linspace(0.4, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=lavenderpink)

t = np.linspace(0.37, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=lavenderpink)

t = np.linspace(0.3, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=lavenderpink)

t = np.linspace(0.25, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=lavenderpink)

t = np.linspace(0.3, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=lavenderpink)

t = np.linspace(0.42, 0.899, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=lavenderpink)

t = np.linspace(0.5, 0.899, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=lavenderpink)

t = np.linspace(0.57, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=lavenderpink)

t = np.linspace(0.59, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=lavenderpink)

t = np.linspace(0.62, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=lavenderpink)

t = np.linspace(0.65, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=lavenderpink)

t = np.linspace(0.66, 0.96, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=lavenderpink)

t = np.linspace(0.66, 0.98, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=lavenderpink)

t = np.linspace(0.66, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=lavenderpink)

t = np.linspace(0.67, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=lavenderpink)

t = np.linspace(0.67, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=lavenderpink)

t = np.linspace(0.68, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 20, color=lavenderpink)

t = np.linspace(0.84, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 21, color=lavenderpink)

t = np.linspace(0.98, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.29, 1.36]), np.array([-2.62, 1.78]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 22, color=lavenderpink)

# Color lines 60
t = np.linspace(0.49, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.34, 0.69, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.27, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.655, 0.745, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.21, 0.31, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.74, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.165, 0.25, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.79, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.121, 0.2, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.825, 0.838, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.085, 0.16, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.853, 0.862, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.045, 0.11, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.87, -0.83]), np.array([-3.16, -3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

# Color lines 61
t = np.linspace(0.34, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.345, -1.25]), np.array([-2.443, 0.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.14, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.345, -1.25]), np.array([-2.443, 0.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07, bezier_points[:, 1], color=violet)

t = np.linspace(0.21, 0.96, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.345, -1.25]), np.array([-2.443, 0.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.3, 0.99, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.345, -1.25]), np.array([-2.443, 0.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.68, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.345, -1.25]), np.array([-2.443, 0.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.87, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.345, -1.25]), np.array([-2.443, 0.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.99, 1, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.345, -1.25]), np.array([-2.443, 0.21]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] - 0.07 * 6, bezier_points[:, 1], color=violet)

# Color lines 62
t = np.linspace(0.28, 0.41, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.49, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=razz)

t = np.linspace(0.13, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=razz)

t = np.linspace(0.13, 0.66, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=razz)

t = np.linspace(0.13, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=razz)

t = np.linspace(0.135, 0.799, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=razz)

t = np.linspace(0.145, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=razz)

t = np.linspace(0.149, 0.9455, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=razz)

t = np.linspace(0.158, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=razz)

t = np.linspace(0.17, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=razz)

t = np.linspace(0.17, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=razz)

t = np.linspace(0.18, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=razz)

t = np.linspace(0.19, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0.2, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.24, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=razz)

t = np.linspace(0.32, 0.69, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=razz)

t = np.linspace(0.4, 0.56, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.897, 1.753]), np.array([-2.83, 2.16]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=razz)

# Color lines 63
t = np.linspace(0.4, 0.73, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] + 0.07, color=orchid)

t = np.linspace(0.42, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.43, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=orchid)

t = np.linspace(0.43, 0.69, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=orchid)

t = np.linspace(0.43, 0.668, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=orchid)

t = np.linspace(0.41, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=orchid)

t = np.linspace(0.39, 0.63, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=orchid)

t = np.linspace(0.35, 0.61, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=orchid)

t = np.linspace(0.32, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=orchid)

t = np.linspace(0.28, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=orchid)

t = np.linspace(0.23, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=orchid)

t = np.linspace(0.17, 0.53, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=orchid)

t = np.linspace(0.12, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=orchid)

t = np.linspace(0.03, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=orchid)

t = np.linspace(0.06, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=orchid)

t = np.linspace(0.08, 0.623, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=orchid)

t = np.linspace(0.2, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=orchid)

t = np.linspace(0.3, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=orchid)

t = np.linspace(0.44, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=orchid)

t = np.linspace(0.55, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=orchid)

t = np.linspace(0.68, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=orchid)

t = np.linspace(0.79, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.027, 0.575]), np.array([-3.926, 0.85]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 20, color=orchid)

# Color lines 64
t = np.linspace(0.17, 0.37, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.15, 0.4, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.13, 0.42, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.12, 0.45, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.1, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.08, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.07, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.05, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.04, 0.18, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.46, 0.62, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.29, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.2, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.1, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.15, 0.72, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.2, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.23, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.26, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.4, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.69, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.704, -0.386]), np.array([-4.215, -1.99]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=lavenderpink)

# Color lines 65
t = np.linspace(0.76, 0.797, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=orchid)

t = np.linspace(0.71, 0.805, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=orchid)

t = np.linspace(0.66, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=orchid)

t = np.linspace(0.62, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=orchid)

t = np.linspace(0.58, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=orchid)

t = np.linspace(0.58, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=orchid)

t = np.linspace(0.46, 0.49, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=orchid)

t = np.linspace(0.59, 0.845, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=orchid)

t = np.linspace(0.41, 0.5, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=orchid)

t = np.linspace(0.6, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=orchid)

t = np.linspace(0.36, 0.505, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=orchid)

t = np.linspace(0.6, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=orchid)

t = np.linspace(0.32, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=orchid)

t = np.linspace(0.61, 0.8621, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=orchid)

t = np.linspace(0.27, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=orchid)

t = np.linspace(0.62, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=orchid)

t = np.linspace(0.62, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=orchid)

t = np.linspace(0.21, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=orchid)

t = np.linspace(0.17, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=orchid)

t = np.linspace(0.62, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=orchid)

t = np.linspace(0.14, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=orchid)

t = np.linspace(0.62, 0.899, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=orchid)

t = np.linspace(0.12, 0.505, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=orchid)

t = np.linspace(0.61, 0.905, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=orchid)

t = np.linspace(0.1, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=orchid)

t = np.linspace(0.61, 0.915, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=orchid)

t = np.linspace(0.32, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=orchid)

t = np.linspace(0.6, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=orchid)

t = np.linspace(0.6, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=orchid)

t = np.linspace(0.77, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.44, -1]), np.array([-4.32, -1.034]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=orchid)

# Color lines 66
t = np.linspace(0.05, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.05, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.04, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.03, 0.82, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.07, 0.825, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.105, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.14, 0.84, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.18, 0.845, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.22, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.255, 0.86, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.29, 0.36, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.65, 0.866, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.75, 0.87, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.83, 0.878, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.37, 0.64, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.41, 0.74, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.45, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.48, 0.889, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.52, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.56, 0.905, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 17, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.6, 0.914, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 18, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.638, 0.92, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 19, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.67, 0.925, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 20, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.71, 0.932, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 21, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.75, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 22, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.781, 0.945, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 23, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.82, 0.95, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 24, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.86, 0.96, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 25, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.9, 0.965, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 26, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.93, 0.971, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 27, bezier_points[:, 1], color=lavenderpink)

t = np.linspace(0.967, 0.98, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.182, -3.78]), np.array([-4.6, -2.037]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 28, bezier_points[:, 1], color=lavenderpink)

# Color lines 67
t = np.linspace(0.43, 0.453, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.42, 0.483, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07, color=razz)

t = np.linspace(0.41, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 2, color=razz)

t = np.linspace(0.398, 0.55, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 3, color=razz)

t = np.linspace(0.38, 0.59, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 4, color=razz)

t = np.linspace(0.37, 0.62, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 5, color=razz)

t = np.linspace(0.36, 0.65, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 6, color=razz)

t = np.linspace(0.35, 0.68, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 7, color=razz)

t = np.linspace(0.34, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 8, color=razz)

t = np.linspace(0.32, 0.75, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 9, color=razz)

t = np.linspace(0.31, 0.78, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 10, color=razz)

t = np.linspace(0.3, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 11, color=razz)

t = np.linspace(0.29, 0.85, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 12, color=razz)

t = np.linspace(0.27, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 13, color=razz)

t = np.linspace(0.26, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 14, color=razz)

t = np.linspace(0.25, 0.94, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 15, color=razz)

t = np.linspace(0.27, 0.91, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=razz)

t = np.linspace(0.22, 0.235, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 16, color=razz)

t = np.linspace(0.34, 0.88, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=razz)

t = np.linspace(0.21, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 17, color=razz)

t = np.linspace(0.2, 0.36, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=razz)

t = np.linspace(0.4, 0.83, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 18, color=razz)

t = np.linspace(0.19, 0.42, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=razz)

t = np.linspace(0.47, 0.77, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 19, color=razz)

t = np.linspace(0.17, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 20, color=razz)

t = np.linspace(0.16, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 21, color=razz)

t = np.linspace(0.15, 0.44, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-3.185, -2.17]), np.array([-1.78, -2.006]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1] - 0.07 * 22, color=razz)

# Color lines 68
t = np.linspace(0.1, 0.159, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=razz)

t = np.linspace(0.11, 0.25, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=razz)

t = np.linspace(0.12, 0.35, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=razz)

t = np.linspace(0.13, 0.43, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=razz)

t = np.linspace(0.14, 0.51, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=razz)

t = np.linspace(0.15, 0.6, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=razz)

t = np.linspace(0.16, 0.7, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=razz)

t = np.linspace(0.17, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=razz)

t = np.linspace(0.179, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=razz)

t = np.linspace(0.189, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=razz)

t = np.linspace(0.2, 0.89, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=razz)

t = np.linspace(0.2, 0.9, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=razz)

t = np.linspace(0.21, 0.93, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=razz)

t = np.linspace(0.3, 0.96, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.64, -1.9]), np.array([-3.21, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=razz)

# Color lines 69
t = np.linspace(0.078, 0.099, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color=violet)

t = np.linspace(0.07, 0.14, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07, bezier_points[:, 1], color=violet)

t = np.linspace(0.065, 0.19, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 2, bezier_points[:, 1], color=violet)

t = np.linspace(0.06, 0.24, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 3, bezier_points[:, 1], color=violet)

t = np.linspace(0.052, 0.29, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 4, bezier_points[:, 1], color=violet)

t = np.linspace(0.048, 0.33, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 5, bezier_points[:, 1], color=violet)

t = np.linspace(0.04, 0.38, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 6, bezier_points[:, 1], color=violet)

t = np.linspace(0.03, 0.43, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 7, bezier_points[:, 1], color=violet)

t = np.linspace(0.027, 0.47, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 8, bezier_points[:, 1], color=violet)

t = np.linspace(0.02, 0.52, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 9, bezier_points[:, 1], color=violet)

t = np.linspace(0.01, 0.57, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 10, bezier_points[:, 1], color=violet)

t = np.linspace(0, 0.62, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 11, bezier_points[:, 1], color=violet)

t = np.linspace(0, 0.67, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 12, bezier_points[:, 1], color=violet)

t = np.linspace(0.1, 0.71, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 13, bezier_points[:, 1], color=violet)

t = np.linspace(0.2, 0.76, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 14, bezier_points[:, 1], color=violet)

t = np.linspace(0.33, 0.81, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 15, bezier_points[:, 1], color=violet)

t = np.linspace(0.5, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([linear_bezier(t, np.array([-2.695, -1.686]), np.array([-2.98, -3.27]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0] + 0.07 * 16, bezier_points[:, 1], color=violet)

# Hair and face outline
t = np.linspace(0, 1, 100).reshape(-1, 1)
bezier_points = np.array([cubic_bezier(t, np.array([1.344, 0.35]), np.array([1.064, 0.262]), np.array([1.157, 0.102]), np.array([0.849, 0.248]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.03, 0.419]), np.array([0.4, -0.05]), np.array([0.387, 0.452]), np.array([0.849, 0.248]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.344, 0.35]), np.array([1.83, 0.52]), np.array([0.644, 1.285]), np.array([0.8, 2.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.22, 2.215]), np.array([2.007, 2.73]), np.array([0.933, 2.6]), np.array([0.8, 2.11]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.22, 2.215]), np.array([2.45, 1.44]), np.array([2.65, 0.71]), np.array([2.64, -0.03]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.937, -1.83]), np.array([2.15, -1.6]), np.array([2.61, -1.06]), np.array([2.64, -0.03]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

t = np.linspace(0, 0.8, 100).reshape(-1, 1)
bezier_points = np.array([cubic_bezier(t, np.array([1.937, -1.83]), np.array([1.905, -2.36]), np.array([1.02, -3.75]), np.array([-1.16, -1.166]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

t = np.linspace(0, 1, 100).reshape(-1, 1)
bezier_points = np.array([cubic_bezier(t, np.array([0.60295, -2.6037]), np.array([-0.56, -2.18]), np.array([-2.16, -2.19]), np.array([-2.62, 0.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.035, 4.46]), np.array([-2.64, 3.36]), np.array([-2.79, 1.95]), np.array([-2.62, 0.69]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.035, 4.46]), np.array([-0.02, 5.055]), np.array([1.4, 4.57]), np.array([1.785, 3.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.35, 1.766]), np.array([2.18, 2.68]), np.array([1.94, 3.13]), np.array([1.785, 3.62]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.467, 1.314]), np.array([2.99, 2.12]), np.array([2.44, 2.5]), np.array([2.5, 2.746]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.834, 1.046]), np.array([3.158, 1.91]), np.array([3.172, 2.482]), np.array([2.5, 2.746]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.834, 1.046]), np.array([2.646, 0.516]), np.array([3.003, -0.1]), np.array([3.785, 0.114]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([4.113, 1.154]), np.array([4.3, 0.603]), np.array([4.215, 0.228]), np.array([3.785, 0.114]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([4.113, 1.154]), np.array([4.3, 0.603]), np.array([4.215, 0.228]), np.array([3.58, 0.121]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([3.176, 1.628]), np.array([2.504, 0.274]), np.array([3.29, 0.082]), np.array([3.58, 0.121]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([3.176, 1.628]), np.array([3.43, 2.455]), np.array([3.08, 3.26]), np.array([2.45, 3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.196, 5]), np.array([1.605, 4.83]), np.array([1.95, 4.44]), np.array([2.45, 3.64]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.196, 4.999]), np.array([-0.1, 5.66]), np.array([-1.49, 5.54]), np.array([-2.498, 4.54]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-3.5, -0.05]), np.array([-4.28, 2.73]), np.array([-3.23, 4.245]), np.array([-2.498, 4.54]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-3.5, -0.05]), np.array([-4.28, -1.12]), np.array([-3.93, -2.524]), np.array([-4.76, -3.186]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.0894, -0.975]), np.array([-1.74, -1.86]), np.array([-1.12, -3.44]), np.array([-3.01, -3.76]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.633, 0.211]), np.array([3.24, -1.08]), np.array([2.13, -2.6]), np.array([4.4, -3.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.563, -2.501]), np.array([1.8, -4.39]), np.array([2.34, -3.44]), np.array([4.44, -3.53]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.92, 0.82]), np.array([-2.6, -0.15]), np.array([-3.6, -0.85]), np.array([-3.57, -1.826]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.47, -3.48]), np.array([-3.23, -3.06]), np.array([-3.54, -2.686]), np.array([-3.57, -1.826]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.47, -3.48]), np.array([-3.46, -2.98]), np.array([-3.786, -1.61]), np.array([-2.98, -0.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.594, 0.5375]), np.array([-2.59, 0.24]), np.array([-2.56, -0.192]), np.array([-2.98, -0.7]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-3.36, 0.346]), np.array([-3.554, 1.016]), np.array([-3.011, 0.965]), np.array([-2.92, 0.821]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-3.36, 0.346]), np.array([-3.325, 0.23]), np.array([-3.15, -0.15]), np.array([-3.0273, -0.2692]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.24256, -0.66766]), np.array([-2.38, -0.81]), np.array([-2.593, -0.944]), np.array([-2.844, -0.514]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.16, 0.72]), np.array([0.55, 1.35]), np.array([0.09, 2.99]), np.array([-1.72, 1.97]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.107, -0.34]), np.array([0.88, -0.186]), np.array([0.28, -0.58]), np.array([-0.243, -0.68]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.107, -0.34]), np.array([1.225, -0.18]), np.array([1.544, -0.354]), np.array([1.776, -0.37]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.24304, -0.67995]), np.array([-0.035, -1.04]), np.array([1.56, -1.305]), np.array([1.776, -0.37]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.24304, -0.67995]), np.array([0.63, -0.47]), np.array([0.927, -0.55]), np.array([1.776, -0.37]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.24304, -0.67995]), np.array([0.3, -0.99]), np.array([1.426, -0.92]), np.array([1.776, -0.37]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.04, 1.88]), np.array([-1.86, 2.7]), np.array([-0.62, 2.84]), np.array([-0.29, 2.525]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.04, 1.88]), np.array([-1.68, 2.31]), np.array([-1.296, 2.55]), np.array([-0.877, 2.413]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.29, 2.5242]), np.array([-0.44, 2.492]), np.array([-0.735, 2.43]), np.array([-0.877, 2.413]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.2, 2.51]), np.array([1.083, 2.63]), np.array([1.694, 2.814]), np.array([1.852, 2.853]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.158, 2.56]), np.array([2.1, 2.675]), np.array([1.984, 2.776]), np.array([1.852, 2.853]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.158, 2.56]), np.array([1.94, 2.673]), np.array([1.588, 2.662]), np.array([1.216, 2.5]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.34, 1.75]), np.array([-0.52, 2.12]), np.array([-1.23, 1.985]), np.array([-1.55, 1.475]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.02, 2]), np.array([1.81, 2.146]), np.array([1.424, 2.3]), np.array([1.026, 1.787]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.1226, 1.7614]), np.array([1.89, 1.544]), np.array([1.237, 1.625]), np.array([0.9607, 1.5977]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.1226, 1.7614]), np.array([1.708, 2.428]), np.array([1.116, 1.865]), np.array([0.9607, 1.5977]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.982, 1.68]), np.array([1.886, 2.258]), np.array([1.116, 1.865]), np.array([0.9607, 1.5977]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.776, 1.628]), np.array([1.924, 1.738]), np.array([1.914, 1.807]), np.array([1.831, 1.9346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.58756, 1.6098]), np.array([1.793, 1.702]), np.array([1.743, 1.913]), np.array([1.67472, 1.97805]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.283, 1.605]), np.array([1.228, 1.666]), np.array([1.222, 1.767]), np.array([1.247, 1.852]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.345, 1.763]), np.array([1.331, 1.838]), np.array([1.463, 1.921]), np.array([1.514, 1.857]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.345, 1.763]), np.array([1.3756, 1.6185]), np.array([1.561, 1.7943]), np.array([1.514, 1.857]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.7405, 2.0667]), np.array([1.796, 2.226]), np.array([1.761, 2.1074]), np.array([1.695, 2.0736]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.891, 2.008]), np.array([1.974, 2.281]), np.array([1.9, 2.053]), np.array([1.801, 2.05]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.978, 1.943]), np.array([2.209, 2.138]), np.array([2.018, 1.981]), np.array([1.943, 1.97]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.066, 1.8424]), np.array([2.288, 2.086]), np.array([2.105, 1.884]), np.array([1.999, 1.921]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.066, 1.8424]), np.array([2.158, 1.814]), np.array([2.361, 1.882]), np.array([2.1065, 1.782]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.08, 1.727]), np.array([2.443, 1.823]), np.array([2.147, 1.7505]), np.array([2.1065, 1.782]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.0673, -0.8037]), np.array([0.023, -0.779]), np.array([0.02, -0.7253]), np.array([0.0007, -0.626]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.16, -0.821]), np.array([0.185, -0.788]), np.array([0.249, -0.702]), np.array([0.2495, -0.583]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.2596, -0.792]), np.array([0.229, -0.757]), np.array([0.249, -0.702]), np.array([0.2495, -0.583]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.2596, -0.792]), np.array([0.3048, -0.8203]), np.array([0.5023, -0.8095]), np.array([0.5215, -0.725]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.542, -0.541]), np.array([0.544, -0.57]), np.array([0.54, -0.666]), np.array([0.5215, -0.725]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.848, -0.779]), np.array([0.679, -0.802]), np.array([0.55, -0.84]), np.array([0.5215, -0.725]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([0.848, -0.779]), np.array([0.9318, -0.765]), np.array([0.898, -0.6]), np.array([0.87, -0.504]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.1994, -0.71]), np.array([1.013, -0.746]), np.array([0.8877, -0.814]), np.array([0.9024, -0.675]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.1994, -0.71]), np.array([1.2735, -0.686]), np.array([1.212, -0.502]), np.array([1.195, -0.469]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.232, -0.643]), np.array([1.32, -0.68]), np.array([1.413, -0.663]), np.array([1.438, -0.599]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.3577, -0.4455]), np.array([1.394, -0.48]), np.array([1.453, -0.576]), np.array([1.438, -0.599]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([1.573, -0.407]), np.array([1.634, -0.566]), np.array([1.4664, -0.603]), np.array([1.435, -0.561]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([2.62315, -3.66877]), np.array([0.49, -6.13]), np.array([-0.9, -4.76]), np.array([-3.01, -3.76]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-4.77, -3.66]), np.array([-4.405, -3.77]), np.array([-3.51, -3.57]), np.array([-3.01, -3.76]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-3.04, -0.03]), np.array([-3.41, 0.42]), np.array([-3.27, 0.964]), np.array([-2.953, 0.644]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.64, -0.635]), np.array([-2.465, -0.711]), np.array([-2.446, -0.469]), np.array([-2.545, -0.432]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-2.64, -0.635]), np.array([-2.739, -0.589]), np.array([-2.718, -0.396]), np.array([-2.545, -0.432]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.51, 1.372]), np.array([-0.836, 1.244]), np.array([-0.556, 1.41]), np.array([-0.147, 1.511]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.51, 1.372]), np.array([-1.28, 1.662]), np.array([-0.905, 2.116]), np.array([-0.147, 1.511]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.3324, 1.3435]), np.array([-1.182, 1.606]), np.array([-0.94, 2.168]), np.array([-0.147, 1.511]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.56, 1.39416]), np.array([-0.98, 1.3]), np.array([-1.134, 1.382]), np.array([-1.2564, 1.47826]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.733, 1.363]), np.array([-0.573, 1.419]), np.array([-0.534, 1.679]), np.array([-0.714, 1.813]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.95715, 1.3559]), np.array([-1.091, 1.42]), np.array([-1.1388, 1.5623]), np.array([-1.0916, 1.6947]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.728, 1.631]), np.array([-0.681, 1.536]), np.array([-0.812, 1.434]), np.array([-0.906, 1.498]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.728, 1.631]), np.array([-0.819, 1.767]), np.array([-1.008, 1.6]), np.array([-0.906, 1.498]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.34305, 1.65668]), np.array([-0.249, 1.552]), np.array([-0.306, 1.5]), np.array([-0.5608, 1.394]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.45634, 1.44]), np.array([-1.645, 1.369]), np.array([-1.794, 1.396]), np.array([-1.51, 1.372]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.45634, 1.44]), np.array([-1.76, 1.59]), np.array([-1.541, 1.47]), np.array([-1.404, 1.501]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.3457, 1.5704]), np.array([-1.536, 1.609]), np.array([-1.585, 1.697]), np.array([-1.404, 1.501]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.3457, 1.5704]), np.array([-1.624, 1.859]), np.array([-1.428, 1.629]), np.array([-1.249, 1.666]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.163, 1.73]), np.array([-1.363, 1.742]), np.array([-1.58, 1.967]), np.array([-1.249, 1.666]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.163, 1.73]), np.array([-1.45, 2.138]), np.array([-1.128, 1.717]), np.array([-1.1, 1.763]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.987, -1.1745]), np.array([-0.9386, -1.114]), np.array([-1.027, -0.985]), np.array([-1.1074, -1.0016]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.987, -1.1745]), np.array([-1.0264, -1.2294]), np.array([-1.2344, -1.0456]), np.array([-1.1074, -1.0016]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.892, 1.828]), np.array([-0.974, 1.88]), np.array([-1.025, 2.047]), np.array([-0.9644, 1.8146]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.05, 1.79]), np.array([-1.128, 2.031]), np.array([-1.054, 1.852]), np.array([-0.9644, 1.8146]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-1.05, 1.79]), np.array([-1.088, 1.807]), np.array([-1.296, 2.032]), np.array([-1.101, 1.762]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.89, 1.83]), np.array([-0.883, 2.017]), np.array([-0.923, 1.963]), np.array([-0.8286, 1.8319]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.7607, 1.8282]), np.array([-0.807, 2.043]), np.array([-0.756, 1.947]), np.array([-0.8286, 1.8319]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.7607, 1.8282]), np.array([-0.628, 2.01]), np.array([-0.7, 1.969]), np.array([-0.671, 1.813]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([cubic_bezier(t, np.array([-0.556, 1.774]), np.array([-0.54, 2.09]), np.array([-0.553, 1.794]), np.array([-0.671, 1.813]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

# Polygon edges
bezier_points = np.array([linear_bezier(t, np.array([-0.03349, -2.405]), np.array([-1.733, -2.14]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.87, -2.954]), np.array([-1.733, -2.14]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.87, -2.954]), np.array([0.0001, -2.4146]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.87, -2.954]), np.array([-0.6536, -2.308]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.87, -2.954]), np.array([-1.51, -3.33]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.245, -2.6]), np.array([-1.51, -3.33]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.745, -2.8115]), np.array([-1.51, -3.33]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.42, -4.57]), np.array([-1.51, -3.33]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.42, -4.57]), np.array([-1.985, -3.277]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.0443, -4.253]), np.array([-1.97, -3.3]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.45527, -4.08606]), np.array([-0.5, -2.724]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.72, -4.872]), np.array([-1.4554, -4.0872]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.72, -4.872]), np.array([-0.3, -4.1]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.68, -2.982]), np.array([-0.3, -4.1]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.178, -3.69]), np.array([-0.3, -4.1]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.826, -3.54]), np.array([-0.564, -3.324]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.826, -3.54]), np.array([1.13, -2.675]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.17, -4.21]), np.array([0.573, -5.03]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.17, -4.21]), np.array([0.826, -3.54]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.17, -4.21]), np.array([2.03, -4.273]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.17, -4.21]), np.array([-0.72, -4.872]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.817, -3.547]), np.array([-0.3, -4.1]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.496, -3.49]), np.array([0.176, -2.47]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.826, -3.54]), np.array([1.72, -3.25]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([2.03, -4.27]), np.array([1.45, -3.34]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.973, 3.73]), np.array([-0.0208, 4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.19, 2.9]), np.array([-0.14, 4.375]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.27, 3.04]), np.array([-0.242, 4.71]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.766, 3.1373]), np.array([1.1888, 4.339]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.4705, 2.589]), np.array([1.462, 2.5367]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.486, 2.739]), np.array([1.5578, 3.291]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.8772, 3.353]), np.array([0.27, 3.04]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.618, 4]), np.array([-1.7, 2.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.67, 3.014]), np.array([-0.0835, 2.6287]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.27, 3.04]), np.array([-0.4, 2.26]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.27, 3.04]), np.array([1.045, 2.407]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.849, 2.217]), np.array([1.3, 1.95]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.823, 2.5175]), np.array([1.5464, 2.0626]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.645, 1.37]), np.array([1.5107, 1.6067]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.9, 1.48]), np.array([2.19, 1.286]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.7214, 0.3323]), np.array([2.377, 1.668]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.455, 0.45]), np.array([2.63, -0.07]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.742, -0.48]), np.array([2.628, -0.2346]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.574, -0.332]), np.array([1.1762, 0.265]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.77, -2.127]), np.array([1.9, -2]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.23, -0.937]), np.array([1.937, -1.83]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.23, -0.937]), np.array([0.588, -2.6]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.07856, -1.2377]), np.array([0.588, -2.6]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.5227, -1]), np.array([-0.4417, -1.561]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.539, -0.416]), np.array([0.42, 0.24]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.7, 2.2176]), np.array([-1.5, 2.08]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.8, 2.3]), np.array([-2.64, 1.98]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.937, 1.13]), np.array([-2.64, 1.98]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.94, 1.12]), np.array([-1.39, -0.49]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.94, 1.12]), np.array([-2.58, 0.465]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.26, -0.3]), np.array([-0.53, -1.085]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.287, 0.58]), np.array([-1.39, -0.49]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.259, -0.3]), np.array([-1.37, 0.65]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.259, -0.3]), np.array([0.186, 0.26]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.06, 0.1]), np.array([-0.44, 1.016]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.2757, 1.4132]), np.array([-0.65, 0.9]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.795, 2.08]), np.array([0.206, 1.682]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.0344, 1.23]), np.array([0.463, 0.704]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.272, 1.031]), np.array([0.694, 0.307]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.205, 2.175]), np.array([-0.418, 1.707]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.51, 2.08]), np.array([-1.74, 1.254]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.5436, 1.375]), np.array([-1.937, 1.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.37, 0.65]), np.array([-1.937, 1.13]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.37, 0.65]), np.array([-0.65, 0.9]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.56, 1.4]), np.array([-0.65, 0.9]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.7, -1.5]), np.array([-1.39, -0.49]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.374, -0.33]), np.array([-1.39, -0.49]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.53, -1.085]), np.array([-1.39, -0.49]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.7, -1.5]), np.array([-0.53, -1.085]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.3, -2.323]), np.array([-0.53, -1.085]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([3.3912, -2.6937]), np.array([2.8578, -3.63655]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([2.85779, -3.63659]), np.array([2.23065, -2.312097]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.60749, -2.8015]), np.array([2.66122864, -1.9739363]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([2.0636, -1.685]), np.array([2.98382, -2.1299]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([2.8595, -1.25426]), np.array([2.2458, -1.42994]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.2905, -3.6938]), np.array([-4.28509, -2.46609]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.5287588, -2.2295799]), np.array([-4.25118, -2.36166]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.5732015, -2.05487547]), np.array([-3.4055, -2.207]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.01, -3.76]), np.array([-2.873936, -3.2288488]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.867197563, -3.202544017]), np.array([-2.5732015, -2.0548755]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.829308, -3.04598]), np.array([-2.76, -1.806]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.842278, -1.661832]), np.array([-2.76, -1.806]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.76, -1.806]), np.array([-2.5926968, -0.7835917]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.360421, -1.3787748]), np.array([-2.76, -1.806]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.931293, -0.972575]), np.array([-3.488999, -1.28728616]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.820856, -0.643777]), np.array([-3.088, -0.4]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.2907716, -1.1870325]), np.array([-3.3155255, -0.861993]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.872403, 0.23215]), np.array([-2.6, 0.213]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.700707, 0.8651]), np.array([-3.373977, 0.757303]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.86, 1.685]), np.array([-3.168, 0.909214]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.6716722, 1.6097255]), np.array([-3.52008, 1.9546]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.8970455, 2.567985]), np.array([-3.7746, 1.70405]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.58805, 2.2911]), np.array([-3.56843, 3.1696]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.39507, 2.89088]), np.array([-2.63, 3.31]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-3.5684363, 3.16960005]), np.array([-2.63, 3.31]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.49799998, 4.54000003]), np.array([-2.63, 3.31]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-2.49799998, 4.54000003]), np.array([-1.5960092, 4.0103182]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-1.57, 5.176]), np.array([-1.33304636, 4.2391292]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.5276996, 5.409519]), np.array([-0.9891865, 4.4859772]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([-0.13, 5.39]), np.array([0.444105, 4.6645665]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([0.9736413, 5.1043627]), np.array([0.44412, 4.66458]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([1.582264, 4.757799]), np.array([1.4667, 4.103]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([2.45, 3.64]), np.array([1.90686, 3.27331]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([2.8302, 1.03512]), np.array([2.96518, 1.09327]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([3.02888, 2.18597]), np.array([3.17596, 1.62794]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')

bezier_points = np.array([linear_bezier(t, np.array([2.7256, 2.629195]), np.array([3.0914, 2.9255]))]).reshape(-1, 2)
plt.plot(bezier_points[:, 0], bezier_points[:, 1], color='black')


plt.xlim(-8.57, 8.57)
plt.ylim(-6, 6)
plt.show()
